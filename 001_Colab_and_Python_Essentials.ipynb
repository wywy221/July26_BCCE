# %% [markdown]
# <a href="https://colab.research.google.com/github/wywy221/July26_BCCE/blob/main/001_Colab_and_Python_Essentials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="right" src="https://github.com/codeBMB/April26_Rutgers-RCSB/raw/main/images/PyBMB_logo.png" width="150" height="150" />
#
# # Project: CodeBMB: Computational Literacy for Biochemistry and Molecular Biology Education
# ## Notebook: Colab and Python Essentials
#
# **Purpose:**
# Google Colab is a free, cloud-based Jupyter notebook environment that lets you write and run Python code directly in your browser — no installation needed! This notebook combines everything you need to get comfortable in Colab with the core building blocks of the Python language: variables, data types, lists, loops, and logic. By the end of today, you'll be able to open a notebook, run code, troubleshoot common hiccups, and write short Python programs of your own.

# %% [markdown]
# ## Steps
# 1.   Navigate, edit, and execute code in a Google Colab notebook.
# 2.   Understand the basics of Python syntax, variables, data types, and operations.
# 3.   Import a dataset from GitHub — a skill you'll reuse in every notebook this series.
#
# ## Questions
# *   What is Google Colab, and how do I use it to run Python code?
# *   What is Python, and why is it useful for biochemistry and molecular biology?
# *   How do I get data into a Colab notebook so I can work with it?
#
# ## Learning Objectives
# *   Get comfortable copying, saving, and running a Colab notebook
# *   Install a package and import data from GitHub
# *   Work with variables, data types, lists, and slices
# *   Use `for` loops to repeat operations
# *   Use `if` statements to make decisions in code

# %% [markdown]
# ## Section 1 — Making a Copy
#
# When you open someone else's notebook, it's **read-only**. Making a copy saves it to your own Google Drive so you can edit and save changes.
#
# **How to make a copy:**
# 1. Click **File → Save a copy in Drive** from the top menu.
# 2. A new tab will open with *your own editable copy* — it's automatically named **"Copy of [original name]"**.
# 3. You can rename it by clicking on the title at the top of the page.
#
# > **Always** make a copy before editing a shared notebook! Go ahead and make your copy now before continuing.

# %% [markdown]
# ## Section 2 — Saving Your Work
#
# Colab **auto-saves** your notebook to Google Drive every few minutes, but you can also save manually.
#
# **Saving options:**
# - **Auto-save:** Happens automatically in the background.
# - **Manual save:** Press `Ctrl + S` (Windows/Linux) or `Cmd + S` (Mac), or go to **File → Save**.
# - **Save a copy in Drive:** File → Save a copy in Drive (creates a new file).
# - **Download:** File → Download → Download .ipynb (saves a local copy to your computer).
#
# > All saved notebooks live in your Google Drive under **Colab Notebooks** unless you move them.

# %% [markdown]
# ## Section 3 — Text Blocks & Code Blocks
#
# Colab notebooks are made up of two types of **cells** (blocks):
#
# ### Text (Markdown) Cells
# Used for writing explanations, headings, and notes. They support **Markdown** formatting:
# - `# Heading 1`, `## Heading 2` — for headings
# - `**bold**` → **bold**, `*italic*` → *italic*
# - `` `code` `` → `code`
# - `- item` or `1. item` → bullet or numbered lists
#
# Double-click any text cell to **edit** it. Click outside or press `Shift + Enter` to render it.
#
# ### Code Cells
# Used to write and run code. You can also write comments in your code in these boxes by typing `#` at the beginning of a line or after a line of code.
#
# **Adding new cells:**
# - Hover between cells to see **+ Code** and **+ Text** buttons.
# - Or use the top toolbar buttons which say **+ Code** and **+ Text**.
#
# Try double-clicking this cell to see the raw Markdown, then click outside to render it again.

# %% [markdown]
# ## Section 4 — The Play Button (Running Cells)
#
# The **play button** (▶) is how you execute a code cell.
#
# **Ways to run a cell:**
# - Click the ▶ **play button** on the left side of the cell.
# - Press `Shift + Enter` — runs the current cell and moves to the next one.
# - Press `Ctrl + Enter` — runs the current cell and stays on it.
#
# **What the icons mean:**
# - **Spinning circle** — the cell is currently running.
# - ✅ **Green checkmark** — the cell ran successfully.
# - ❌ **Red X** — there was an error. Read the message below the cell — it usually tells you exactly what went wrong and where.
#
# Try running the cell below!

# %%
# Click the ▶ play button to run this cell!
import datetime

now = datetime.datetime.now()
print(f"You ran this cell at: {now.strftime('%I:%M %p on %B %d, %Y')}")
print("Great job running a cell! ✅")

# %% [markdown]
# ## Section 5 — Code Commenting
#
# Code commenting is an important element for reproducibility and sharing of code. Think of comments like a lab notebook entry — a guide for your future self and others to make it easier to understand and rerun the code.
#
# ### Commenting in Code Cells
# In Python code, use `#` for single-line comments:
# ```python
# # This is a comment — Python ignores this line
# x = 5  # You can also add comments at the end of a line
# ```
#
# Good commenting habits will make everything else in this notebook easier to read — including your own code a week from now!

# %%
# Good commenting practice in Python
# Add comments describing what is happening in each step. You can run the code if it helps.

temperatures_celsius = [0, 20, 37, 100]

temperatures_fahrenheit = [(c * 9/5) + 32 for c in temperatures_celsius]

print("Celsius → Fahrenheit")
print("-" * 25)
for c, f in zip(temperatures_celsius, temperatures_fahrenheit):
    print(f"  {c}°C  →  {f}°F")

# %% [markdown]
# ## Section 6 — Installing Libraries & Packages
#
# Colab comes with many popular Python libraries pre-installed (like NumPy, Pandas, and Matplotlib — you'll meet these in the next notebook). But sometimes you need to install additional ones.
#
# Use the `!pip install` command inside a code cell:
#
# ```python
# !pip install package-name
# ```
#
# The `!` at the start tells Colab to run this as a **terminal/shell command** rather than Python code. Let's try installing a small, fun package.

# %%
# Install a package using pip
# 'emoji' is a fun library that lets you use emojis in Python
# !pip install emoji --quiet

# Now import and use it
import emoji
print(emoji.emojize("Python is :snake: awesome! :party_popper:"))

# %% [markdown]
# Now try to write your own code and print out one (or more!) emojis. The basic code is shown under the comment.
#
# A list of [possible emoji codes](https://carpedm20.github.io/emoji/).

# %%
# Copy and modify the code below with new emoji codes:
print(emoji.emojize("I write code on a :desktop_computer:"))

# now you try!

# %% [markdown]
# ## Section 7 — Uploading & Importing Data
#
# Files can be brought into Colab through three main methods:
#
# 1.   **Direct upload** — Click the file icon at left, and drag your file into the space.
# 2.   **Google Drive** — Connect Colab to a Google Drive folder.
# 3.   **Import from GitHub** — Read a file directly from a GitHub repository link.
#
# **Note:** Data uploaded to Colab is not private and Colab is not compliant with US privacy laws such as FERPA or HIPAA. Do not upload data that contains private information or proprietary/unpublished results.
#
# ### Connecting to Google Drive
# Mounting your Drive gives Colab access to your files, which is useful when you want to save outputs somewhere permanent.

# %%
# Mount Google Drive
# After running this cell, click the link, sign in, and copy the authorization code.

from google.colab import drive
drive.mount('/content/drive')

print("\n✅ Google Drive mounted successfully!")
print("Your Drive files are accessible at: /content/drive/MyDrive/")

# %% [markdown]
# ### Importing Data Directly from GitHub
#
# You don't need to download-then-upload a file if it's already hosted on GitHub — you can read it directly into Python using its **raw** link. This is the method we'll use throughout this workshop series, including in the very next notebook, so it's worth getting comfortable with now.
#
# The `pandas` library (which comes pre-installed in Colab) has a function called `read_csv()` that can read a `.csv` file straight from a URL.

# %%
# Example: read a CSV file directly from a raw GitHub link
# import the pandas package
import pandas as pd

# the raw GitHub link to the data file
file = "https://github.com/codeBMB/July26_BCCE/raw/main/data/bsa_std_curve.csv"

# read the file into a dataframe
df = pd.read_csv(file)

# display the top part of the file
display(df.head())

# %% [markdown]
# > 💡 **Keep this pattern handy** — `pd.read_csv("link-to-file")` — you'll use this exact skill to load the datasets in the next notebook, *Pandas and NumPy*.

# %% [markdown]
# ## Section 8 — Variables and Data Types
#
# Any Python interpreter can work just like a calculator. This is not very useful on its own — try running the following cell. What do you think the output will be?

# %%
3 + 9

# %% [markdown]
# Here, Python has performed a calculation for us. To save this value, or other values, we assign them to a variable for later use. The syntax for assigning variables is the following:
#
# ```python
# variable_name = variable_value
# ```
#
# Let's put this to work with something a biochemist would actually calculate: the **Michaelis-Menten equation**, which describes enzyme reaction velocity:
#
# $$v = \frac{V_{max} \cdot [S]}{K_m + [S]}$$
#
# In the next cell, declare `Km = 15.0`, `Vmax = 100.0`, and a substrate concentration `substrate_conc = 50.0` (micromolar), then calculate and print `velocity` using the equation above.

# %%
# Calculations using the Michaelis-Menten Equation

# %% [markdown]
# <details>
# <summary>🔍 CLICK TO SEE ANSWER</summary>
#
# ```python
# # 1. Declare the parameters
# Km = 15.0     # micromolar
# Vmax = 100.0  # nanomoles/second
# substrate_conc = 50.0  # micromolar
#
# # 2. Set up the equation
# velocity = Vmax * substrate_conc / (Km + substrate_conc)
#
# # 3. Print the results
# print(velocity)
# ```
# Note: You can change the values and see what happens!
# </details>

# %% [markdown]
# Notice several things about this code. You can use `#` to add comments to your code, both at the start of a line and in the middle of the line — the computer does not act on these comments. They're used here to remind the user what units are used for each value.
#
# When choosing variable names, you should pick something descriptive (`velocity` rather than `v` or `x`) — your future self will thank you.

# %%
print(velocity)

# %% [markdown]
# Note that if you do not specify a new name for a variable, then referencing it doesn't automatically change the value of that variable. However, you *can* reassign a variable to a new value by overwriting it — this is worth doing carefully.

# %%
print(velocity)
velocity = velocity * 60
print(velocity)

# %% [markdown]
# There are situations where it is reasonable to overwrite a variable with a new value, but you should always think carefully about this. Usually it is better practice to give the variable a new name and leave the existing variable as-is.

# %%
# change velocity back
velocity = velocity / 60
v_nmols_per_min = velocity * 60
print(velocity)
print(v_nmols_per_min)

# %% [markdown]
# ## Exercise
# In the code cell below, create a variable called **`Km2`** and set it to `30`.
# Then **`print(Km2)`**.

# %% [markdown]
# <details>
# <summary>🔍 CLICK TO SEE ANSWER</summary>
#
# ```python
# # 1. Define the variable
# Km2 = 30     # micromolar
#
# # 2. Print the value of Km2
# print(Km2)
# ```
# </details>

# %% [markdown]
# ## Section 9 — Data Types
#
# Each variable is some particular type of data. The most common types are strings (`str`), integers (`int`), and floating point numbers (`float`). You can identify the data type of any variable with the function `type(variable_name)`.

# %%
type(velocity)

# %% [markdown]
# You can change the data type of a variable — this is called **casting**.

# %%
velocity_string = str(velocity)
type(velocity_string)

# %% [markdown]
# ## Exercise
# In the code cell below, convert `velocity` to an **integer** with `int()` and print the result. As you start to type, Colab will often make suggestions that you can use by simply pressing the tab key.

# %% [markdown]
# <details>
# <summary>🔍 CLICK TO SEE ANSWER</summary>
#
# ```python
# # 1. Change the data type
# velocity_int = int(velocity)
#
# # 2. Print the results
# print(type(velocity_int))
# ```
# </details>

# %% [markdown]
# ## Section 10 — Lists
#
# Another common data structure in Python is the **list**. Lists group several values together and are declared using square brackets `[ ]`. **Python assigns special meanings to square brackets `[]`, parentheses `()`, and curly brackets `{}`, so you must be very careful with these characters.** List values are separated by commas.
#
# The built-in function `len()` can be used to determine the length of a list.

# %%
# This is a list
substrate_concs = [1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 10.0, 15.0, 20.0, 30.0, 50.0, 75.0, 100.0]  # micromolar

# I can determine its length
s_length = len(substrate_concs)

# Print the length of the list
print('This list contains', s_length, 'substrate concentrations')

# %% [markdown]
# Note the format of the print statement above:
#
# ```python
# print('text', variable, 'text')
# ```
#
# f-strings are another approach to printing in Python, and they're simpler to format — you never have to guess where the spaces will be:
#
# ```python
# print(f'text {variable} text {variable}')
# ```
#
# Try this print statement:

# %%
print(f'This list contains {s_length} substrate concentrations.')

# %% [markdown]
# You can use an element of a list as a variable in a calculation by referencing its position, or **index**. Remember that counting starts at zero, so the first element of a list is `list_name[0]`.

# %%
# Convert the last substrate concentration to nM
concentration_nM = substrate_concs[12] * 1000
print(concentration_nM)

# %% [markdown]
# You can also add something to the end of a list using the `.append()` function.

# %%
substrate_concs.append(1000.0)
print(substrate_concs)

# %% [markdown]
# ## Exercise
# 1. Print the **last value** in `substrate_concs` using
#    `print(substrate_concs[len(substrate_concs) - 1])`.
# 2. Then add the value **200.0** to the end of the list with
#    `substrate_concs.append(200.0)` and `print(substrate_concs)` to check.

# %%
# Print the last value in the list substrate_concs, then add 200.0 to the end of the list.

# %% [markdown]
# <details>
# <summary>🔍 CLICK TO SEE ANSWER</summary>
#
# ```python
# # 1. Print the last value in substrate_concs
# print(substrate_concs[len(substrate_concs) - 1])
#
# # 2. Add the value 200.0 to the end of the list
# substrate_concs.append(200.0)
# print(substrate_concs)
# ```
# </details>

# %% [markdown]
# ## Section 11 — Slices
#
# Sometimes you will want to make a new list that is a subset of an existing list — for example, just the first few elements. This is called a `slice`. The general syntax is
#
# ```python
# new_list = list_name[start:end]
# ```
#
# If you do not include a start index, the slice automatically starts at `list_name[0]`. If you do not include an end index, the slice automatically goes to the end of the list. Remember that the end index is **not included** in the result.

# %%
# Reset the substrate_concs list
substrate_concs = [1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 10.0, 15.0, 20.0, 30.0, 50.0, 75.0, 100.0]  # micromolar
short_list = substrate_concs[0:3]
print(short_list)

# %% [markdown]
# ## Check your understanding
# What does the following code print?
#
# ```python
# slice1 = substrate_concs[8:]
# slice2 = substrate_concs[:3]
# print('slice1 is', slice1)
# print('slice2 is', slice2)
# ```
#
# <details>
# <summary>🔍 CLICK TO SEE ANSWER</summary>
#
# ```
# slice1 is [20.0, 30.0, 50.0, 75.0, 100.0]
# slice2 is [1.0, 2.0, 3.0]
# ```
# </details>

# %% [markdown]
# ## Exercise
# Make a slice called **`first_three`** that contains the first three values of `substrate_concs`, then `print(first_three)`.

# %% [markdown]
# ## Section 12 — For Loops: Repeating an Operation Many Times
#
# Often, you will want to do something to every element of a list. The structure to do this is called a `for` loop. The general structure is:
#
# ```python
# for variable in list:
#     do things using variable
# ```
#
# Indentation is very important in Python. There is nothing like an `end` statement that tells you the loop is finished — the indentation shows you what statements belong to the loop.

# %%
substrate_concs = [1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 10.0, 15.0, 20.0, 30.0, 50.0, 75.0, 100.0]
Km, Vmax = 15.0, 100.0

for number in substrate_concs:
    velocity = Vmax * number / (Km + number)
    print(velocity)

# %% [markdown]
# It would be even better if, instead of just printing the values, we saved them in a new list. To do this, we use the `append` function — but the list has to already exist (even if empty) *before* the loop starts.

# %%
velocities = []
substrate_concs = [1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 10.0, 15.0, 20.0, 30.0, 50.0, 75.0, 100.0]

for number in substrate_concs:
    V = Vmax * number / (Km + number)
    velocities.append(V)

print(velocities)

# %% [markdown]
# ## Exercise
# Write a loop that converts the temperatures in `temp` to Kelvin and prints the new list.

# %%
# Fix the code below
# list of temperatures to convert
temp = [0, 100, 273.15]

#

# iterate through temp list
for t in temp:
  t += t + 273.15

# print the resulting temperatures
print(temp)

# %% [markdown]
# ## Section 13 — Making Choices: Logic Statements
#
# Within your code, you may need to evaluate a variable and then do something if it has a particular value. This type of logic is handled by an `if` statement.

# %%
temp = 35       # a number we want to check
if temp > 30:   # a condition ends with a colon
  print("Hot")  # the action is indented

# %% [markdown]
# You can combine an `if` statement with a `for` loop — for example, when we're only interested in the lower substrate concentrations, as we might do when looking for the initial linear portion of a Michaelis-Menten curve.

# %%
Km, Vmax = 15.0, 100.0
linear_MM = []

substrate_concs = [1.0, 2.0, 3.0, 4.0, 6.0, 8.0, 10.0, 15.0, 20.0, 30.0, 50.0, 75.0, 100.0]
for number in substrate_concs:
    if number < Km/4:
        V_linear = Vmax * number / (Km + number)
        linear_MM.append(V_linear)

print(linear_MM)

# %% [markdown]
# Other logic operations include:
# - equal to `==`
# - not equal to `!=`
# - greater than `>`
# - less than `<`
# - greater than or equal to `>=`
# - less than or equal to `<=`
#
# You can also use `and`, `or`, and `not` to check more than one condition at a time — we'll practice this more in the extra practice notebook.
#
# ## Warm-up — write your own `if`
# In the code cell below:
# 1. Set **`score = 85`**.
# 2. Write an `if` statement that prints **"Great!"** only when `score` is **80 or higher**.
# 3. Change the value of `score` to see how that affects the output.

# %% [markdown]
# <details>
# <summary>🔍 CLICK TO SEE ANSWER</summary>
#
# ```python
# score = 85
# if score >= 80:
#     print("Great!")
# ```
# </details>

# %% [markdown]
# ## Summary & What's Next
#
# Congratulations! You've made it through the essentials of Colab and Python. Here's a quick recap of what you learned today:
#
# | Topic | What You Learned |
# |---|---|
# | **Make a Copy / Save** | Getting your own editable copy and saving your work |
# | **Text & Code Cells** | Adding and editing Markdown and Python cells |
# | **Running Cells** | Using the play button and reading success/error indicators |
# | **Commenting** | Documenting code with `#` |
# | **Installing Packages** | Using `!pip install` |
# | **Importing Data** | Mounting Drive and reading a `.csv` straight from GitHub with `pd.read_csv()` |
# | **Variables & Data Types** | Assigning values, `type()`, and casting |
# | **Lists** | Creating, indexing, `len()`, and `.append()` |
# | **Slices** | Pulling a subset of a list with `[start:end]` |
# | **For Loops** | Repeating a calculation across every item in a list |
# | **If Statements** | Making decisions in code with comparison operators |
#
# **Want more practice, or curious about other Colab features** like forms, sharing, exporting, or Gemini AI? Check out the companion notebook: **[Colab Reference & Extra Practice](https://github.com/codeBMB/July26_BCCE/raw/main/001b_Colab_Reference_and_Extra_Practice.ipynb)**.
#
# **Up next:** In the following notebook, *Pandas and NumPy*, you'll take the `pd.read_csv()` skill from Section 7 and the variables/lists/loops you just practiced, and use them to explore real datasets in a **dataframe** — a much more powerful way to organize biochemical data than a plain list.
